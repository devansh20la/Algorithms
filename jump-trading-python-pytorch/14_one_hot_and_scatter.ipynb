# %% [markdown]
# # One-Hot Encoding with Scatter
#
# These PyTorch prompts are AI/ML-focused practice problems designed for the role brief. They are not claimed to be previously asked by Jump Trading; they target PyTorch fundamentals interviewers often test.

# %% [markdown]
# ## Interview Prompt
#
# Implement `one_hot(labels, num_classes)` using PyTorch tensor operations. `labels` can have any shape; return a float tensor with one extra final dimension of size `num_classes`.

# %% [markdown]
# ## PyTorch Concepts Tested
#
# - Scatter
# - Dtype/device handling
# - Arbitrary rank tensors

# %% [markdown]
# ## Constraints
#
# - Do not call `torch.nn.functional.one_hot`
# - Output shape is `labels.shape + (num_classes,)`
# - Output dtype is `torch.float32`
# - Use the same device as `labels`

# %% [markdown]
# ## Examples
#
# ```python
# labels = torch.tensor([2, 0])
# one_hot(labels, 3) -> tensor([[0., 0., 1.], [1., 0., 0.]])
# ```

# %% [markdown]
# ## Starter Code
#
# Fill in the implementation. As in a real interview, explain tensor shapes at every step before optimizing.

# %%
import torch

def one_hot(labels: torch.Tensor, num_classes: int) -> torch.Tensor:
    """Return one-hot encoded labels without using F.one_hot."""
    raise NotImplementedError

# %% [markdown]
# ## Sample Tests
#
# Run this cell after implementing your solution. Add extra edge cases, especially around shape, dtype, and device behavior.

# %%
import torch

labels = torch.tensor([2, 0])
out = one_hot(labels, 3)
expected = torch.tensor([[0., 0., 1.], [1., 0., 0.]])
assert torch.equal(out, expected)

labels_2d = torch.tensor([[1, 2], [0, 1]])
out = one_hot(labels_2d, 3)
assert out.shape == (2, 2, 3)
assert torch.equal(out[0, 0], torch.tensor([0., 1., 0.]))
print('sample tests passed')

# %% [markdown]
# ## Interview Follow-Ups
#
# - What does `scatter_` do in-place?
# - How would you validate class indices?
# - Why is one-hot inefficient for large vocabularies?

# %% [markdown]
# ## Complexity and Shape Notes
#
# Write your final notes after solving.
#
# - Input shapes:
# - Output shape:
# - Time:
# - Extra memory:
