# %% [markdown]
# # Manual Cross Entropy Loss
#
# These PyTorch prompts are AI/ML-focused practice problems designed for the role brief. They are not claimed to be previously asked by Jump Trading; they target PyTorch fundamentals interviewers often test.

# %% [markdown]
# ## Interview Prompt
#
# Implement `cross_entropy_from_logits(logits, targets)` for multi-class classification using `log_softmax` and gather/indexing. Return the mean negative log-likelihood.

# %% [markdown]
# ## PyTorch Concepts Tested
#
# - Logits vs probabilities
# - Gathering target classes
# - Numerical stability

# %% [markdown]
# ## Constraints
#
# - `logits` shape is `(batch, num_classes)`
# - `targets` shape is `(batch,)` and dtype long
# - Do not call `torch.nn.functional.cross_entropy`
# - Return a scalar tensor

# %% [markdown]
# ## Examples
#
# ```python
# logits = torch.tensor([[2., 0.]])
# targets = torch.tensor([0])
# cross_entropy_from_logits(logits, targets) is small but positive
# ```

# %% [markdown]
# ## Starter Code
#
# Fill in the implementation. As in a real interview, explain tensor shapes at every step before optimizing.

# %%
import torch

def cross_entropy_from_logits(logits: torch.Tensor, targets: torch.Tensor) -> torch.Tensor:
    """Return mean cross entropy from raw logits and integer targets."""
    raise NotImplementedError

# %% [markdown]
# ## Sample Tests
#
# Run this cell after implementing your solution. Add extra edge cases, especially around shape, dtype, and device behavior.

# %%
import torch
import torch.nn.functional as F

logits = torch.tensor([[2., 0., -1.], [0., 3., 1.]], requires_grad=True)
targets = torch.tensor([0, 1])
out = cross_entropy_from_logits(logits, targets)
expected = F.cross_entropy(logits, targets)
assert out.shape == torch.Size([])
assert torch.allclose(out, expected)
out.backward()
assert logits.grad is not None
print('sample tests passed')

# %% [markdown]
# ## Interview Follow-Ups
#
# - Why should cross entropy take logits instead of softmax probabilities?
# - How would you add class weights?
# - How would you ignore a padding label such as `-100`?

# %% [markdown]
# ## Complexity and Shape Notes
#
# Write your final notes after solving.
#
# - Input shapes:
# - Output shape:
# - Time:
# - Extra memory:
