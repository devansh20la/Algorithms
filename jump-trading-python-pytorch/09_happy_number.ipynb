# %% [markdown]
# # Happy Number
#
# Source note: Publicly reported Jump Trading interview questions are sparse and sometimes second-hand. This notebook is based on a reported Jump prompt or a recurring Jump-tagged coding theme. Treat it as interview practice, not an official question bank.
#
# **Reported signal:** Listed as a Jump-tagged LeetCode-style question in public interview data.

# %% [markdown]
# ## Interview Prompt
#
# Implement `is_happy(n)` that returns whether repeatedly replacing `n` with the sum of squares of its digits eventually reaches 1.

# %% [markdown]
# ## Constraints
#
# - 1 <= n <= 2**31 - 1
# - Detect cycles
# - Avoid recursion depth risks

# %% [markdown]
# ## Examples
#
# ```python
# is_happy(19) -> True
# is_happy(2) -> False
# ```

# %% [markdown]
# ## Starter Code
#
# Implement the function or class below. Keep your first pass simple and correct, then discuss complexity and edge cases out loud as you would in an interview.

# %%
def is_happy(n: int) -> bool:
    """Return True if n is a happy number."""
    raise NotImplementedError

# %% [markdown]
# ## Sample Tests
#
# Run this cell after implementing your solution. Add your own edge cases before considering the problem complete.

# %%
assert is_happy(1) is True
assert is_happy(19) is True
assert is_happy(2) is False
assert is_happy(7) is True
print('sample tests passed')

# %% [markdown]
# ## Interview Follow-Ups
#
# - Can you solve with Floyd's cycle detection?
# - What is the maximum next value for a 32-bit integer?
# - Why does the process always enter a cycle?

# %% [markdown]
# ## Complexity Notes
#
# Write your final time and space complexity here after solving.
#
# - Time:
# - Space:
