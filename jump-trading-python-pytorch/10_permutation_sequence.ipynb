# %% [markdown]
# # Kth Permutation Sequence
#
# Source note: Publicly reported Jump Trading interview questions are sparse and sometimes second-hand. This notebook is based on a reported Jump prompt or a recurring Jump-tagged coding theme. Treat it as interview practice, not an official question bank.
#
# **Reported signal:** Listed as a Jump-tagged hard LeetCode-style recursion/backtracking question.

# %% [markdown]
# ## Interview Prompt
#
# Given `n` and `k`, return the kth lexicographic permutation of the numbers `1..n` without generating all permutations.

# %% [markdown]
# ## Constraints
#
# - 1 <= n <= 9
# - 1 <= k <= n!
# - Return a string such as `'213'`
# - Target O(n^2) or better

# %% [markdown]
# ## Examples
#
# ```python
# kth_permutation(3, 3) -> '213'
# kth_permutation(4, 9) -> '2314'
# ```

# %% [markdown]
# ## Starter Code
#
# Implement the function or class below. Keep your first pass simple and correct, then discuss complexity and edge cases out loud as you would in an interview.

# %%
def kth_permutation(n: int, k: int) -> str:
    """Return the kth lexicographic permutation of 1..n, using 1-indexed k."""
    raise NotImplementedError

# %% [markdown]
# ## Sample Tests
#
# Run this cell after implementing your solution. Add your own edge cases before considering the problem complete.

# %%
assert kth_permutation(3, 1) == '123'
assert kth_permutation(3, 3) == '213'
assert kth_permutation(4, 9) == '2314'
assert kth_permutation(1, 1) == '1'
print('sample tests passed')

# %% [markdown]
# ## Interview Follow-Ups
#
# - Why convert `k` from 1-indexed to 0-indexed?
# - What is the factorial number system?
# - How would repeated values change the problem?

# %% [markdown]
# ## Complexity Notes
#
# Write your final time and space complexity here after solving.
#
# - Time:
# - Space:
