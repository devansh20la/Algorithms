# %% [markdown]
# # Batched Gather Embeddings
#
# These PyTorch prompts are AI/ML-focused practice problems designed for the role brief. They are not claimed to be previously asked by Jump Trading; they target PyTorch fundamentals interviewers often test.

# %% [markdown]
# ## Interview Prompt
#
# Implement `batched_embedding_lookup(embedding_table, token_ids)` where `embedding_table` has shape `(vocab_size, hidden)` and `token_ids` has shape `(batch, seq_len)`. Return embeddings of shape `(batch, seq_len, hidden)`.

# %% [markdown]
# ## PyTorch Concepts Tested
#
# - Tensor indexing
# - Embedding lookup
# - Shape contracts

# %% [markdown]
# ## Constraints
#
# - Use PyTorch tensor operations
# - Do not one-hot encode the full vocabulary
# - `token_ids` is a `LongTensor`
# - Output device should match `embedding_table`

# %% [markdown]
# ## Examples
#
# ```python
# embedding_table.shape == (1000, 64)
# token_ids.shape == (8, 32)
# output.shape == (8, 32, 64)
# ```

# %% [markdown]
# ## Starter Code
#
# Fill in the implementation. As in a real interview, explain tensor shapes at every step before optimizing.

# %%
import torch

def batched_embedding_lookup(embedding_table: torch.Tensor, token_ids: torch.Tensor) -> torch.Tensor:
    """Return embeddings for a batch of token ids."""
    raise NotImplementedError

# %% [markdown]
# ## Sample Tests
#
# Run this cell after implementing your solution. Add extra edge cases, especially around shape, dtype, and device behavior.

# %%
import torch

embedding_table = torch.arange(5 * 3).reshape(5, 3).float()
token_ids = torch.tensor([[0, 2, 4], [3, 1, 0]])
out = batched_embedding_lookup(embedding_table, token_ids)
assert out.shape == (2, 3, 3)
assert torch.equal(out[0, 1], embedding_table[2])
assert torch.equal(out[1, 0], embedding_table[3])
print('sample tests passed')

# %% [markdown]
# ## Interview Follow-Ups
#
# - How is this related to `nn.Embedding`?
# - What dtype must index tensors use?
# - How would gradients flow into the embedding table?

# %% [markdown]
# ## Complexity and Shape Notes
#
# Write your final notes after solving.
#
# - Input shapes:
# - Output shape:
# - Time:
# - Extra memory:
