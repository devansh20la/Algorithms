# %% [markdown]
# # Find Nearby String Matches
#
# Source note: Publicly reported Jump Trading interview questions are sparse and sometimes second-hand. This notebook is based on a reported Jump prompt or a recurring Jump-tagged coding theme. Treat it as interview practice, not an official question bank.
#
# **Reported signal:** Reported as finding indices where two strings match within a parent string.

# %% [markdown]
# ## Interview Prompt
#
# Implement `find_nearby_matches(parent, left, right, max_gap)` returning all starting indices `i` where `left` occurs at `i` and `right` occurs later with at most `max_gap` characters between the end of `left` and start of `right`.

# %% [markdown]
# ## Constraints
#
# - Return indices in ascending order
# - Matches may overlap
# - All inputs are ASCII strings
# - `max_gap >= 0`
# - Target better than checking every pair when there are many matches

# %% [markdown]
# ## Examples
#
# ```python
# find_nearby_matches('abcXXdefabcYdef', 'abc', 'def', 2) -> [0, 8]
# ```

# %% [markdown]
# ## Starter Code
#
# Implement the function or class below. Keep your first pass simple and correct, then discuss complexity and edge cases out loud as you would in an interview.

# %%
def find_nearby_matches(parent: str, left: str, right: str, max_gap: int) -> list[int]:
    """Return start indices of `left` that are followed by nearby `right`."""
    raise NotImplementedError

# %% [markdown]
# ## Sample Tests
#
# Run this cell after implementing your solution. Add your own edge cases before considering the problem complete.

# %%
assert find_nearby_matches('abcXXdefabcYdef', 'abc', 'def', 2) == [0, 8]
assert find_nearby_matches('aaaa', 'aa', 'aa', 0) == [0, 1]
assert find_nearby_matches('abc---def', 'abc', 'def', 2) == []
assert find_nearby_matches('abc--def', 'abc', 'def', 2) == [0]
print('sample tests passed')

# %% [markdown]
# ## Interview Follow-Ups
#
# - How would you use KMP or rolling hashes?
# - How do overlapping matches affect correctness?
# - What if `parent` is a stream?

# %% [markdown]
# ## Complexity Notes
#
# Write your final time and space complexity here after solving.
#
# - Time:
# - Space:
