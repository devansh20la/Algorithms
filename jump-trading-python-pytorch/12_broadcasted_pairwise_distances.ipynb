# %% [markdown]
# # Broadcasted Pairwise Distances
#
# These PyTorch prompts are AI/ML-focused practice problems designed for the role brief. They are not claimed to be previously asked by Jump Trading; they target PyTorch fundamentals interviewers often test.

# %% [markdown]
# ## Interview Prompt
#
# Implement `pairwise_squared_distances(x, y)` where `x` has shape `(n, d)` and `y` has shape `(m, d)`. Return a tensor of shape `(n, m)` containing squared Euclidean distances, using PyTorch broadcasting.

# %% [markdown]
# ## PyTorch Concepts Tested
#
# - Broadcasting
# - Vectorization
# - Memory and numerical reasoning

# %% [markdown]
# ## Constraints
#
# - Do not use explicit Python loops over `n` or `m`
# - Return shape `(n, m)`
# - Preserve dtype/device where possible
# - Handle empty `n` or `m` dimensions

# %% [markdown]
# ## Examples
#
# ```python
# x = torch.tensor([[0., 0.], [1., 0.]])
# y = torch.tensor([[0., 1.]])
# pairwise_squared_distances(x, y) -> tensor([[1.], [2.]])
# ```

# %% [markdown]
# ## Starter Code
#
# Fill in the implementation. As in a real interview, explain tensor shapes at every step before optimizing.

# %%
import torch

def pairwise_squared_distances(x: torch.Tensor, y: torch.Tensor) -> torch.Tensor:
    """Return squared L2 distances between every row of x and every row of y."""
    raise NotImplementedError

# %% [markdown]
# ## Sample Tests
#
# Run this cell after implementing your solution. Add extra edge cases, especially around shape, dtype, and device behavior.

# %%
import torch

x = torch.tensor([[0., 0.], [1., 0.]])
y = torch.tensor([[0., 1.], [2., 0.]])
out = pairwise_squared_distances(x, y)
expected = torch.tensor([[1., 4.], [2., 1.]])
assert torch.allclose(out, expected)
assert out.shape == (2, 2)
assert pairwise_squared_distances(x[:0], y).shape == (0, 2)
print('sample tests passed')

# %% [markdown]
# ## Interview Follow-Ups
#
# - What is the memory cost of `x[:, None, :] - y[None, :, :]`?
# - Can you implement this with matrix multiplication?
# - Why can small negative distances appear in the matmul version?

# %% [markdown]
# ## Complexity and Shape Notes
#
# Write your final notes after solving.
#
# - Input shapes:
# - Output shape:
# - Time:
# - Extra memory:
