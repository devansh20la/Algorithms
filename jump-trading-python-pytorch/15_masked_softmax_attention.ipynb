# %% [markdown]
# # Masked Softmax for Attention
#
# These PyTorch prompts are AI/ML-focused practice problems designed for the role brief. They are not claimed to be previously asked by Jump Trading; they target PyTorch fundamentals interviewers often test.

# %% [markdown]
# ## Interview Prompt
#
# Implement `masked_softmax(scores, mask, dim=-1)`. `scores` contains attention logits and `mask` is boolean with `True` for valid positions. Invalid positions should receive probability 0.

# %% [markdown]
# ## PyTorch Concepts Tested
#
# - Boolean masking
# - Softmax stability
# - Attention mechanics

# %% [markdown]
# ## Constraints
#
# - Support broadcasting-compatible mask shapes
# - Return probabilities with the same shape as `scores`
# - Rows with at least one valid position should sum to 1 over `dim`
# - Avoid NaNs for normal valid rows

# %% [markdown]
# ## Examples
#
# ```python
# scores = torch.tensor([[1., 2., 3.]])
# mask = torch.tensor([[True, True, False]])
# masked_softmax(scores, mask) -> probabilities with last entry 0
# ```

# %% [markdown]
# ## Starter Code
#
# Fill in the implementation. As in a real interview, explain tensor shapes at every step before optimizing.

# %%
import torch

def masked_softmax(scores: torch.Tensor, mask: torch.Tensor, dim: int = -1) -> torch.Tensor:
    """Apply softmax while assigning zero probability to masked positions."""
    raise NotImplementedError

# %% [markdown]
# ## Sample Tests
#
# Run this cell after implementing your solution. Add extra edge cases, especially around shape, dtype, and device behavior.

# %%
import torch

scores = torch.tensor([[1., 2., 3.], [1., 1., 1.]])
mask = torch.tensor([[True, True, False], [False, True, True]])
out = masked_softmax(scores, mask, dim=-1)
assert out.shape == scores.shape
assert torch.allclose(out[0, 2], torch.tensor(0.0))
assert torch.allclose(out[1, 0], torch.tensor(0.0))
assert torch.allclose(out.sum(dim=-1), torch.ones(2))
print('sample tests passed')

# %% [markdown]
# ## Interview Follow-Ups
#
# - Why do implementations often fill masked logits with `-inf`?
# - What should happen if every position in a row is masked?
# - How does this differ in fp16?

# %% [markdown]
# ## Complexity and Shape Notes
#
# Write your final notes after solving.
#
# - Input shapes:
# - Output shape:
# - Time:
# - Extra memory:
