# %% [markdown]
# # Triplets Where a + b = c
#
# Source note: Publicly reported Jump Trading interview questions are sparse and sometimes second-hand. This notebook is based on a reported Jump prompt or a recurring Jump-tagged coding theme. Treat it as interview practice, not an official question bank.
#
# **Reported signal:** Reported directly as finding all triplets `(a, b, c)` such that `a + b = c`.

# %% [markdown]
# ## Interview Prompt
#
# Given an integer array, return all unique value triplets `(a, b, c)` such that `a + b = c`. A value can be used only as many times as it appears in the input.

# %% [markdown]
# ## Constraints
#
# - Return triplets sorted lexicographically
# - Within each triplet require `a <= b`
# - Handle duplicates correctly
# - Aim for O(n^2) time after sorting or counting

# %% [markdown]
# ## Examples
#
# ```python
# triplets_sum_relation([1, 2, 3, 4, 5]) -> [(1, 2, 3), (1, 3, 4), (1, 4, 5), (2, 3, 5)]
# ```

# %% [markdown]
# ## Starter Code
#
# Implement the function or class below. Keep your first pass simple and correct, then discuss complexity and edge cases out loud as you would in an interview.

# %%
def triplets_sum_relation(nums: list[int]) -> list[tuple[int, int, int]]:
    """Return unique value triplets (a, b, c) with a + b == c."""
    raise NotImplementedError

# %% [markdown]
# ## Sample Tests
#
# Run this cell after implementing your solution. Add your own edge cases before considering the problem complete.

# %%
assert triplets_sum_relation([1, 2, 3, 4, 5]) == [(1, 2, 3), (1, 3, 4), (1, 4, 5), (2, 3, 5)]
assert triplets_sum_relation([0, 0, 0]) == [(0, 0, 0)]
assert triplets_sum_relation([1, 1, 2]) == [(1, 1, 2)]
assert triplets_sum_relation([2, 2, 4, 4]) == [(2, 2, 4)]
assert triplets_sum_relation([5, 6, 7]) == []
print('sample tests passed')

# %% [markdown]
# ## Interview Follow-Ups
#
# - How should negative numbers affect sorting and uniqueness?
# - Can you produce index triplets instead of value triplets?
# - What changes for very large arrays with small integer ranges?

# %% [markdown]
# ## Complexity Notes
#
# Write your final time and space complexity here after solving.
#
# - Time:
# - Space:
