# %% [markdown]
# # Minimum Cost Travel Tickets
#
# Source note: Publicly reported Jump Trading interview questions are sparse and sometimes second-hand. This notebook is based on a reported Jump prompt or a recurring Jump-tagged coding theme. Treat it as interview practice, not an official question bank.
#
# **Reported signal:** Reported as the second part of a Jump coding question: minimize ticket cost over travel days.

# %% [markdown]
# ## Interview Prompt
#
# Given increasing travel days and ticket options `(duration, cost)`, return the minimum cost to cover every travel day. Use default tickets: 1-day `$2`, 7-day `$7`, 30-day `$25`.

# %% [markdown]
# ## Constraints
#
# - `days` is strictly increasing
# - 1 <= day <= 365
# - Use dynamic programming
# - Return 0 if there are no travel days

# %% [markdown]
# ## Examples
#
# ```python
# min_ticket_cost([1,2,3,4,5,11,12,25]) -> 13
# ```

# %% [markdown]
# ## Starter Code
#
# Implement the function or class below. Keep your first pass simple and correct, then discuss complexity and edge cases out loud as you would in an interview.

# %%
def min_ticket_cost(days: list[int], tickets: tuple[tuple[int, int], ...] = ((1, 2), (7, 7), (30, 25))) -> int:
    """Return the minimum cost to cover all travel days."""
    raise NotImplementedError

# %% [markdown]
# ## Sample Tests
#
# Run this cell after implementing your solution. Add your own edge cases before considering the problem complete.

# %%
assert min_ticket_cost([]) == 0
assert min_ticket_cost([1, 2, 3, 4, 5, 11, 12, 25]) == 13
assert min_ticket_cost([1, 4, 6, 7, 8, 20]) == 11
assert min_ticket_cost([1, 2, 3, 4, 5, 6, 7]) == 7
print('sample tests passed')

# %% [markdown]
# ## Interview Follow-Ups
#
# - Can you solve with pointers instead of scanning days?
# - How would arbitrary ticket durations change the recurrence?
# - What state definition makes the proof easiest?

# %% [markdown]
# ## Complexity Notes
#
# Write your final time and space complexity here after solving.
#
# - Time:
# - Space:
