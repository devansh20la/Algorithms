# %% [markdown]
# # Padding Collate Function
#
# These PyTorch prompts are AI/ML-focused practice problems designed for the role brief. They are not claimed to be previously asked by Jump Trading; they target PyTorch fundamentals interviewers often test.

# %% [markdown]
# ## Interview Prompt
#
# Implement `pad_collate(batch, pad_value=0)` for variable-length token sequences. Each batch item is `(tokens, label)`, where `tokens` is a 1D LongTensor. Return padded tokens, sequence lengths, and labels.

# %% [markdown]
# ## PyTorch Concepts Tested
#
# - DataLoader collation
# - Padding
# - Batch shape contracts

# %% [markdown]
# ## Constraints
#
# - Padded token tensor shape is `(batch, max_len)`
# - Lengths shape is `(batch,)`
# - Labels shape is `(batch,)`
# - Preserve token dtype as long
# - Use `pad_value` for trailing positions

# %% [markdown]
# ## Examples
#
# ```python
# batch = [(tensor([4, 5]), 1), (tensor([6]), 0)]
# padded -> tensor([[4, 5], [6, 0]])
# lengths -> tensor([2, 1])
# ```

# %% [markdown]
# ## Starter Code
#
# Fill in the implementation. As in a real interview, explain tensor shapes at every step before optimizing.

# %%
import torch

def pad_collate(batch: list[tuple[torch.Tensor, int]], pad_value: int = 0) -> tuple[torch.Tensor, torch.Tensor, torch.Tensor]:
    """Collate variable-length token sequences into a padded batch."""
    raise NotImplementedError

# %% [markdown]
# ## Sample Tests
#
# Run this cell after implementing your solution. Add extra edge cases, especially around shape, dtype, and device behavior.

# %%
import torch

batch = [(torch.tensor([4, 5]), 1), (torch.tensor([6]), 0), (torch.tensor([7, 8, 9]), 1)]
padded, lengths, labels = pad_collate(batch, pad_value=-1)
assert torch.equal(padded, torch.tensor([[4, 5, -1], [6, -1, -1], [7, 8, 9]]))
assert torch.equal(lengths, torch.tensor([2, 1, 3]))
assert torch.equal(labels, torch.tensor([1, 0, 1]))
print('sample tests passed')

# %% [markdown]
# ## Interview Follow-Ups
#
# - How would you sort by length for packed RNNs?
# - How would you build an attention mask from lengths?
# - Where does this function plug into `DataLoader`?

# %% [markdown]
# ## Complexity and Shape Notes
#
# Write your final notes after solving.
#
# - Input shapes:
# - Output shape:
# - Time:
# - Extra memory:
