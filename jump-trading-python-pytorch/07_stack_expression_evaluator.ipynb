# %% [markdown]
# # Stack Expression Evaluator
#
# Source note: Publicly reported Jump Trading interview questions are sparse and sometimes second-hand. This notebook is based on a reported Jump prompt or a recurring Jump-tagged coding theme. Treat it as interview practice, not an official question bank.
#
# **Reported signal:** Reported as evaluating a string of digits and `+`/`*` operators with a stack.

# %% [markdown]
# ## Interview Prompt
#
# Parse a string one character at a time. If it is a digit, push its integer value. If it is `+` or `*`, pop two values, apply the operator, and push the result. Return `-1` for malformed expressions. Return the final stack value only if exactly one value remains.

# %% [markdown]
# ## Constraints
#
# - Input contains only digits, `+`, and `*`
# - Single digit operands only
# - Malformed means insufficient operands or more than one final value
# - Use an explicit stack

# %% [markdown]
# ## Examples
#
# ```python
# eval_stack_expr('12+4*7*') -> 84
# eval_stack_expr('12') -> -1
# eval_stack_expr('1+') -> -1
# ```

# %% [markdown]
# ## Starter Code
#
# Implement the function or class below. Keep your first pass simple and correct, then discuss complexity and edge cases out loud as you would in an interview.

# %%
def eval_stack_expr(expr: str) -> int:
    """Evaluate the stack expression or return -1 if malformed."""
    raise NotImplementedError

# %% [markdown]
# ## Sample Tests
#
# Run this cell after implementing your solution. Add your own edge cases before considering the problem complete.

# %%
assert eval_stack_expr('12+4*7*') == 84
assert eval_stack_expr('34+') == 7
assert eval_stack_expr('') == -1
assert eval_stack_expr('12') == -1
assert eval_stack_expr('1+') == -1
print('sample tests passed')

# %% [markdown]
# ## Interview Follow-Ups
#
# - How would you support multi-digit integers?
# - How would you add division and error handling?
# - Why is this similar to Reverse Polish Notation?

# %% [markdown]
# ## Complexity Notes
#
# Write your final time and space complexity here after solving.
#
# - Time:
# - Space:
